# %%
import pandas as pd
import os
import json
from keras.api.datasets import cifar10, cifar100
from tf_keras.applications import resnet50, vgg19, mobilenet, efficientnet, mobilenet_v2
import time
import tensorflow as tf
import numpy as np
from sklearn.metrics import accuracy_score
from multiprocessing.pool import Pool

# %%
tf.device('/GPU:0')

# %%
BASE_PATH = '/content/drive/MyDrive/Mestrado/Robustness'
MODELS_PATH = f'{BASE_PATH}/optimization'
CIFAR10_C_PATH = f'{BASE_PATH}/CIFAR-10-C'

CORRUPTION_TYPES = {
    'blur': ['defocus_blur', 'glass_blur', 'motion_blur', 'zoom_blur'],
    'digital': ['contrast', 'elastic_transform', 'jpeg_compression', 'pixelate'],
    'noise': ['gaussian_noise', 'impulse_noise', 'shot_noise'],
    'weather': ['brightness', 'fog', 'frost', 'snow']
}
LEN_BY_SEVERITY_LEVEL = 10000

# %%
def preprocess_images(images, preprocess_input):
    images = images.astype('float32')
    images = preprocess_input(images)
    return images

def generate_data_with_labels(image_dir):
    all_file_paths = []
    labels = []

    all_folds = os.listdir(image_dir)
    for fold in all_folds:
        fold_path = os.path.join(image_dir, fold)
        all_files_in_fold = os.listdir(fold_path)
        for file in all_files_in_fold:
            file_path = os.path.join(fold_path, file)
            all_file_paths.append(file_path)
            labels.append(fold)
    return pd.DataFrame(data={"file_path": all_file_paths, "labels": labels})


def save_json(output_name, data_dict):
    with open(output_name, 'w') as file:
        json.dump(data_dict, file)
    print("File save with success!")


def load_json(output_name):
    with open(output_name, 'r') as file:
        data_dict = json.load(file)
    print("File loaded with success!")

    return data_dict

# %%
def predict_in_tflite(model_tflite_path, images, database_path):
    interpreter = tf.lite.Interpreter(model_tflite_path, num_threads=2)
    interpreter.allocate_tensors()

    input_details = interpreter.get_input_details()[0]
    output_details = interpreter.get_output_details()[0]

    y_predicted = []

    total_images = len(images)

    start_time = time.time()
    i = 0

    for image in images:
        if input_details['dtype'] == np.uint8:
            input_scale, input_zero_point = input_details["quantization"]
            image = image / input_scale + input_zero_point
        image = np.expand_dims(image, axis=0).astype(input_details["dtype"])
        interpreter.set_tensor(input_details['index'], image)
        interpreter.invoke()

        output_data = interpreter.get_tensor(output_details['index'])
        y_predicted.append(np.argmax(output_data))

        if i % 1000 == 0:
            current_time = time.time() - start_time
            print(f"{database_path} - Total images {i} - {current_time:.2f}s")
        i+=1


    execution_time = time.time() - start_time
    print(f"{database_path} - Total images {total_images} - {execution_time:.2f}s")

    return y_predicted


def process_predict(images, labels, subject, corruption_type, severity, model_tflite_path):
    print(f"Process predict started for {subject}/{corruption_type}/{severity}")
    corruption_name = CORRUPTION_TYPES[subject][corruption_type]

    database_path =  f'{subject}/{corruption_name}/{severity}'

    preds = predict_in_tflite(model_tflite_path=model_tflite_path, images=images, database_path=database_path)

    accuracy = accuracy_score(labels, preds)

    return subject, corruption_type, severity, 1 - accuracy

def process_corrupted_images(model_tflite_path, output_path, preprocess_input, x_test_image, y_test_image, CIFAR_C_PATH = f'{BASE_PATH}/CIFAR-10-C'):
    labels = np.load(f"{CIFAR_C_PATH}/labels.npy")

    x_test_image = preprocess_images(x_test_image, preprocess_input)

    result = {
      "clean": None,
      "corruptions": {
        'blur': {},
        'digital': {},
        'noise': {},
        'weather': {}
      }
    }


    # Evaluate clean images
    preds = predict_in_tflite(model_tflite_path=model_tflite_path, images=x_test_image, database_path='clean')
    accuracy = accuracy_score(y_test, preds)
    result["clean"] = 1 - accuracy
    print(f"Accuracy for clean is {accuracy}")

    # Evaluate corrupted images
    for subject in CORRUPTION_TYPES.keys():
        for corruption_type in range(len(CORRUPTION_TYPES[subject])):
            corruption_name = CORRUPTION_TYPES[subject][corruption_type]
            all_images_by_corruption = np.load(f"{CIFAR_C_PATH}/{corruption_name}.npy")
            all_images_by_corruption = preprocess_images(all_images_by_corruption, preprocess_input)
            with Pool(processes=5) as pool:
                tasks = []
                for severity in range(1, 6):
                    current_images = all_images_by_corruption[LEN_BY_SEVERITY_LEVEL * (severity - 1): LEN_BY_SEVERITY_LEVEL * severity]
                    current_labels = labels[LEN_BY_SEVERITY_LEVEL * (severity - 1): LEN_BY_SEVERITY_LEVEL * severity]
                    tasks.append((current_images, current_labels, subject, corruption_type, severity, model_tflite_path))
                output = pool.starmap(process_predict, tasks)

                if corruption_name not in result["corruptions"][subject]:
                    result["corruptions"][subject][corruption_name] = {}
                for response in output:
                    result["corruptions"][subject][corruption_name][response[2]] = response[3]
                save_json(output_path, result)

# %%
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# (x_train, y_train), (x_test, y_test) = cifar100.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 13s 0us/step

# %%
all_preprocess_inputs = {
    'resnet50': resnet50.preprocess_input,
    'vgg19': vgg19.preprocess_input,
    'mobilenet': mobilenet.preprocess_input,
    'mobilenet_v2': mobilenet_v2.preprocess_input,
}

all_models = os.listdir(MODELS_PATH)
for model in all_models:
  fold_path = os.path.join(MODELS_PATH, model, 'models', 'optimizations')
  result_path = os.path.join(MODELS_PATH, model, 'results')

  if not os.path.isdir(fold_path):
    continue

  all_optimizations = os.listdir(fold_path)
  if not model in all_preprocess_inputs:
    raise Exception("Preprocess not found")
  preprocess_input = all_preprocess_inputs[model]
  for optimization in all_optimizations:
    optimization_path = os.path.join(fold_path, optimization)
    result_name =  optimization.replace('-', '_')
    result_name = result_name.replace('.tflite', '.json')
    result_name = f'ce_{result_name}'
    result_name = os.path.join(result_path, result_name)
    if os.path.exists(result_name) or 'full_integer' not in result_name:
      continue
    print(result_name)

    process_corrupted_images(optimization_path, result_name, preprocess_input, x_test, y_test, CIFAR_C_PATH = f'{BASE_PATH}/CIFAR-10-C')
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# Process predict started for noise/1/4
# noise/impulse_noise/4 - Total images 0 - 0.01s
# Process predict started for noise/1/5
# noise/impulse_noise/5 - Total images 0 - 0.01s
# noise/impulse_noise/1 - Total images 1000 - 5.30s
# noise/impulse_noise/2 - Total images 1000 - 5.61s
# noise/impulse_noise/3 - Total images 1000 - 6.52s
# noise/impulse_noise/4 - Total images 1000 - 6.41s
# noise/impulse_noise/5 - Total images 1000 - 6.14s
# noise/impulse_noise/1 - Total images 2000 - 10.84s
# noise/impulse_noise/2 - Total images 2000 - 12.04s
# noise/impulse_noise/3 - Total images 2000 - 12.85s
# noise/impulse_noise/4 - Total images 2000 - 12.74s
# noise/impulse_noise/5 - Total images 2000 - 12.41s
# noise/impulse_noise/1 - Total images 3000 - 16.61s
# noise/impulse_noise/2 - Total images 3000 - 17.62s
# noise/impulse_noise/3 - Total images 3000 - 19.29s
# noise/impulse_noise/4 - Total images 3000 - 18.92s
# noise/impulse_noise/5 - Total images 3000 - 18.76s
# noise/impulse_noise/1 - Total images 4000 - 22.65s
# noise/impulse_noise/2 - Total images 4000 - 23.26s
# noise/impulse_noise/3 - Total images 4000 - 25.19s
# noise/impulse_noise/4 - Total images 4000 - 25.25s
# noise/impulse_noise/5 - Total images 4000 - 24.94s
# noise/impulse_noise/1 - Total images 5000 - 28.88s
# noise/impulse_noise/2 - Total images 5000 - 29.68s
# noise/impulse_noise/3 - Total images 5000 - 31.33s
# noise/impulse_noise/4 - Total images 5000 - 31.45s
# noise/impulse_noise/5 - Total images 5000 - 30.99s
# noise/impulse_noise/1 - Total images 6000 - 34.44s
# noise/impulse_noise/2 - Total images 6000 - 36.13s
# noise/impulse_noise/3 - Total images 6000 - 36.96s
# noise/impulse_noise/4 - Total images 6000 - 37.85s
# noise/impulse_noise/5 - Total images 6000 - 37.40s
# noise/impulse_noise/1 - Total images 7000 - 40.16s
# noise/impulse_noise/2 - Total images 7000 - 42.49s
# noise/impulse_noise/3 - Total images 7000 - 43.26s
# noise/impulse_noise/4 - Total images 7000 - 43.79s
# noise/impulse_noise/5 - Total images 7000 - 43.49s
# noise/impulse_noise/1 - Total images 8000 - 46.13s
# noise/impulse_noise/2 - Total images 8000 - 48.65s
# noise/impulse_noise/3 - Total images 8000 - 49.42s
# noise/impulse_noise/5 - Total images 8000 - 49.23s
# noise/impulse_noise/4 - Total images 8000 - 50.35s
# noise/impulse_noise/1 - Total images 9000 - 51.71s
# noise/impulse_noise/2 - Total images 9000 - 55.13s
# noise/impulse_noise/3 - Total images 9000 - 55.55s
# noise/impulse_noise/5 - Total images 9000 - 55.61s
# noise/impulse_noise/1 - Total images 10000 - 57.53s
# noise/impulse_noise/4 - Total images 9000 - 56.73s
# noise/impulse_noise/2 - Total images 10000 - 60.13s
# noise/impulse_noise/3 - Total images 10000 - 61.29s
# noise/impulse_noise/5 - Total images 10000 - 60.62s
# noise/impulse_noise/4 - Total images 10000 - 61.64s
# File save with success!
# Process predict started for noise/2/1
# noise/shot_noise/1 - Total images 0 - 0.01s
# Process predict started for noise/2/2
# noise/shot_noise/2 - Total images 0 - 0.01s
# Process predict started for noise/2/3
# noise/shot_noise/3 - Total images 0 - 0.01s
# Process predict started for noise/2/4
# noise/shot_noise/4 - Total images 0 - 0.01s
# Process predict started for noise/2/5
# noise/shot_noise/5 - Total images 0 - 0.01s
# noise/shot_noise/1 - Total images 1000 - 5.36s
# noise/shot_noise/2 - Total images 1000 - 6.01s
# noise/shot_noise/3 - Total images 1000 - 6.27s
# noise/shot_noise/4 - Total images 1000 - 6.06s
# noise/shot_noise/5 - Total images 1000 - 6.27s
# noise/shot_noise/1 - Total images 2000 - 11.93s
# noise/shot_noise/3 - Total images 2000 - 11.83s
# noise/shot_noise/2 - Total images 2000 - 12.52s
# noise/shot_noise/5 - Total images 2000 - 11.66s
# noise/shot_noise/4 - Total images 2000 - 12.58s
# noise/shot_noise/3 - Total images 3000 - 16.79s
# noise/shot_noise/1 - Total images 3000 - 18.38s
# noise/shot_noise/2 - Total images 3000 - 18.84s
# noise/shot_noise/5 - Total images 3000 - 18.29s
# noise/shot_noise/4 - Total images 3000 - 19.10s
# noise/shot_noise/3 - Total images 4000 - 22.38s
# noise/shot_noise/1 - Total images 4000 - 24.94s
# noise/shot_noise/2 - Total images 4000 - 25.04s
# noise/shot_noise/5 - Total images 4000 - 24.01s
# noise/shot_noise/4 - Total images 4000 - 25.50s
# noise/shot_noise/3 - Total images 5000 - 27.92s
# noise/shot_noise/2 - Total images 5000 - 30.38s
# noise/shot_noise/1 - Total images 5000 - 31.46s
# noise/shot_noise/5 - Total images 5000 - 30.47s
# noise/shot_noise/4 - Total images 5000 - 31.54s
# noise/shot_noise/3 - Total images 6000 - 34.49s
# noise/shot_noise/2 - Total images 6000 - 36.57s
# noise/shot_noise/1 - Total images 6000 - 37.15s
# noise/shot_noise/5 - Total images 6000 - 36.97s
# noise/shot_noise/4 - Total images 6000 - 37.88s
# noise/shot_noise/3 - Total images 7000 - 40.80s
# noise/shot_noise/2 - Total images 7000 - 41.83s
# noise/shot_noise/1 - Total images 7000 - 42.80s
# noise/shot_noise/5 - Total images 7000 - 43.14s
# noise/shot_noise/4 - Total images 7000 - 44.11s
# noise/shot_noise/3 - Total images 8000 - 47.22s
# noise/shot_noise/1 - Total images 8000 - 48.51s
# noise/shot_noise/2 - Total images 8000 - 48.21s
# noise/shot_noise/5 - Total images 8000 - 49.48s
# noise/shot_noise/4 - Total images 8000 - 50.22s
# noise/shot_noise/3 - Total images 9000 - 52.93s
# noise/shot_noise/2 - Total images 9000 - 54.43s
# noise/shot_noise/1 - Total images 9000 - 54.99s
# noise/shot_noise/4 - Total images 9000 - 55.71s
# noise/shot_noise/5 - Total images 9000 - 55.96s
# noise/shot_noise/3 - Total images 10000 - 58.24s
# noise/shot_noise/2 - Total images 10000 - 60.13s
# noise/shot_noise/1 - Total images 10000 - 61.09s
# noise/shot_noise/4 - Total images 10000 - 61.07s
# noise/shot_noise/5 - Total images 10000 - 61.33s
# File save with success!
# Process predict started for weather/0/1
# weather/brightness/1 - Total images 0 - 0.01s
# Process predict started for weather/0/2
# weather/brightness/2 - Total images 0 - 0.01s
# Process predict started for weather/0/3
# weather/brightness/3 - Total images 0 - 0.01s
# Process predict started for weather/0/4
# weather/brightness/4 - Total images 0 - 0.01s
# Process predict started for weather/0/5
# weather/brightness/5 - Total images 0 - 0.01s
# weather/brightness/1 - Total images 1000 - 5.77s
# weather/brightness/2 - Total images 1000 - 5.48s
# weather/brightness/3 - Total images 1000 - 5.92s
# weather/brightness/4 - Total images 1000 - 6.44s
# weather/brightness/5 - Total images 1000 - 6.59s
# weather/brightness/2 - Total images 2000 - 11.42s
# weather/brightness/1 - Total images 2000 - 11.98s
# weather/brightness/3 - Total images 2000 - 12.22s
# weather/brightness/4 - Total images 2000 - 12.03s
# weather/brightness/5 - Total images 2000 - 13.23s
# weather/brightness/2 - Total images 3000 - 17.42s
# weather/brightness/4 - Total images 3000 - 17.28s
# weather/brightness/1 - Total images 3000 - 18.54s
# weather/brightness/3 - Total images 3000 - 18.42s
# weather/brightness/5 - Total images 3000 - 19.45s
# weather/brightness/2 - Total images 4000 - 23.21s
# weather/brightness/1 - Total images 4000 - 25.00s
# weather/brightness/4 - Total images 4000 - 23.91s
# weather/brightness/3 - Total images 4000 - 24.75s
# weather/brightness/5 - Total images 4000 - 25.25s
# weather/brightness/2 - Total images 5000 - 29.02s
# weather/brightness/1 - Total images 5000 - 31.60s
# weather/brightness/4 - Total images 5000 - 30.58s
# weather/brightness/3 - Total images 5000 - 31.17s
# weather/brightness/5 - Total images 5000 - 30.61s
# weather/brightness/2 - Total images 6000 - 34.96s
# weather/brightness/1 - Total images 6000 - 37.69s
# weather/brightness/3 - Total images 6000 - 37.00s
# weather/brightness/5 - Total images 6000 - 36.11s
# weather/brightness/4 - Total images 6000 - 37.09s
# weather/brightness/2 - Total images 7000 - 41.28s
# weather/brightness/5 - Total images 7000 - 42.00s
# weather/brightness/1 - Total images 7000 - 43.78s
# weather/brightness/3 - Total images 7000 - 43.28s
# weather/brightness/4 - Total images 7000 - 43.67s
# weather/brightness/2 - Total images 8000 - 47.36s
# weather/brightness/5 - Total images 8000 - 47.42s
# weather/brightness/1 - Total images 8000 - 49.68s
# weather/brightness/3 - Total images 8000 - 49.11s
# weather/brightness/4 - Total images 8000 - 50.21s
# weather/brightness/2 - Total images 9000 - 53.83s
# weather/brightness/5 - Total images 9000 - 53.10s
# weather/brightness/1 - Total images 9000 - 55.98s
# weather/brightness/3 - Total images 9000 - 55.34s
# weather/brightness/4 - Total images 9000 - 56.54s
# weather/brightness/5 - Total images 10000 - 57.96s
# weather/brightness/2 - Total images 10000 - 60.02s
# weather/brightness/1 - Total images 10000 - 61.72s
# weather/brightness/3 - Total images 10000 - 61.08s
# weather/brightness/4 - Total images 10000 - 61.77s
# File save with success!
# Process predict started for weather/1/1
# weather/fog/1 - Total images 0 - 0.01s
# Process predict started for weather/1/2
# weather/fog/2 - Total images 0 - 0.01s
# Process predict started for weather/1/3
# weather/fog/3 - Total images 0 - 0.01s
# Process predict started for weather/1/4
# weather/fog/4 - Total images 0 - 0.01s
# Process predict started for weather/1/5
# weather/fog/5 - Total images 0 - 0.01s
# weather/fog/1 - Total images 1000 - 5.74s
# weather/fog/2 - Total images 1000 - 5.80s
# weather/fog/3 - Total images 1000 - 6.09s
# weather/fog/4 - Total images 1000 - 6.24s
# weather/fog/5 - Total images 1000 - 6.48s
# weather/fog/2 - Total images 2000 - 11.26s
# weather/fog/1 - Total images 2000 - 12.29s
# weather/fog/4 - Total images 2000 - 11.74s
# weather/fog/3 - Total images 2000 - 12.81s
# weather/fog/5 - Total images 2000 - 13.20s
# weather/fog/2 - Total images 3000 - 16.71s
# weather/fog/4 - Total images 3000 - 17.32s
# weather/fog/1 - Total images 3000 - 18.93s
# weather/fog/3 - Total images 3000 - 19.35s
# weather/fog/5 - Total images 3000 - 19.63s
# weather/fog/2 - Total images 4000 - 22.68s
# weather/fog/1 - Total images 4000 - 24.79s
# weather/fog/4 - Total images 4000 - 23.57s
# weather/fog/3 - Total images 4000 - 25.28s
# weather/fog/5 - Total images 4000 - 26.15s
# weather/fog/2 - Total images 5000 - 28.63s
# weather/fog/1 - Total images 5000 - 31.03s
# weather/fog/4 - Total images 5000 - 29.81s
# weather/fog/3 - Total images 5000 - 30.93s
# weather/fog/5 - Total images 5000 - 32.35s
# weather/fog/2 - Total images 6000 - 34.63s
# weather/fog/3 - Total images 6000 - 36.70s
# weather/fog/1 - Total images 6000 - 37.52s
# weather/fog/4 - Total images 6000 - 36.35s
# weather/fog/5 - Total images 6000 - 37.80s
# weather/fog/2 - Total images 7000 - 41.18s
# weather/fog/3 - Total images 7000 - 42.26s
# weather/fog/1 - Total images 7000 - 43.93s
# weather/fog/4 - Total images 7000 - 42.99s
# weather/fog/5 - Total images 7000 - 43.12s
# weather/fog/2 - Total images 8000 - 47.44s
# weather/fog/3 - Total images 8000 - 48.69s
# weather/fog/1 - Total images 8000 - 50.05s
# weather/fog/4 - Total images 8000 - 49.46s
# weather/fog/5 - Total images 8000 - 49.11s
# weather/fog/2 - Total images 9000 - 53.60s
# weather/fog/1 - Total images 9000 - 54.74s
# weather/fog/3 - Total images 9000 - 55.24s
# weather/fog/4 - Total images 9000 - 56.10s
# weather/fog/5 - Total images 9000 - 55.60s
# weather/fog/2 - Total images 10000 - 59.63s
# weather/fog/1 - Total images 10000 - 60.24s
# weather/fog/3 - Total images 10000 - 61.04s
# weather/fog/4 - Total images 10000 - 61.41s
# weather/fog/5 - Total images 10000 - 60.90s
# File save with success!
# Process predict started for weather/2/1
# weather/frost/1 - Total images 0 - 0.01s
# Process predict started for weather/2/2
# weather/frost/2 - Total images 0 - 0.01s
# Process predict started for weather/2/3
# weather/frost/3 - Total images 0 - 0.01s
# Process predict started for weather/2/4
# weather/frost/4 - Total images 0 - 0.01s
# Process predict started for weather/2/5
# weather/frost/5 - Total images 0 - 0.01s
# weather/frost/1 - Total images 1000 - 5.21s
# weather/frost/2 - Total images 1000 - 5.99s
# weather/frost/4 - Total images 1000 - 5.76s
# weather/frost/3 - Total images 1000 - 6.39s
# weather/frost/5 - Total images 1000 - 6.53s
# weather/frost/1 - Total images 2000 - 11.33s
# weather/frost/2 - Total images 2000 - 11.66s
# weather/frost/4 - Total images 2000 - 12.02s
# weather/frost/3 - Total images 2000 - 12.62s
# weather/frost/5 - Total images 2000 - 12.96s
# weather/frost/2 - Total images 3000 - 17.05s
# weather/frost/1 - Total images 3000 - 17.83s
# weather/frost/4 - Total images 3000 - 17.47s
# weather/frost/3 - Total images 3000 - 19.11s
# weather/frost/5 - Total images 3000 - 19.43s
# weather/frost/2 - Total images 4000 - 22.51s
# weather/frost/1 - Total images 4000 - 24.16s
# weather/frost/4 - Total images 4000 - 23.22s
# weather/frost/3 - Total images 4000 - 25.20s
# weather/frost/5 - Total images 4000 - 25.70s
# weather/frost/2 - Total images 5000 - 29.01s
# weather/frost/4 - Total images 5000 - 29.12s
# weather/frost/1 - Total images 5000 - 30.55s
# weather/frost/3 - Total images 5000 - 30.60s
# weather/frost/5 - Total images 5000 - 31.96s
# weather/frost/2 - Total images 6000 - 34.70s
# weather/frost/4 - Total images 6000 - 34.59s
# weather/frost/1 - Total images 6000 - 37.00s
# weather/frost/3 - Total images 6000 - 36.99s
# weather/frost/5 - Total images 6000 - 38.49s
# weather/frost/2 - Total images 7000 - 40.42s
# weather/frost/4 - Total images 7000 - 40.91s
# weather/frost/1 - Total images 7000 - 43.46s
# weather/frost/3 - Total images 7000 - 42.75s
# weather/frost/2 - Total images 8000 - 45.68s
# weather/frost/5 - Total images 7000 - 45.04s
# weather/frost/4 - Total images 8000 - 47.47s
# weather/frost/3 - Total images 8000 - 48.57s
# weather/frost/1 - Total images 8000 - 50.05s
# weather/frost/2 - Total images 9000 - 51.04s
# weather/frost/5 - Total images 8000 - 51.09s
# weather/frost/4 - Total images 9000 - 53.56s
# weather/frost/3 - Total images 9000 - 54.79s
# weather/frost/1 - Total images 9000 - 56.45s
# weather/frost/2 - Total images 10000 - 57.06s
# weather/frost/5 - Total images 9000 - 57.23s
# weather/frost/4 - Total images 10000 - 58.90s
# weather/frost/3 - Total images 10000 - 60.16s
# weather/frost/1 - Total images 10000 - 62.08s
# weather/frost/5 - Total images 10000 - 61.91s
# File save with success!
# Process predict started for weather/3/1
# weather/snow/1 - Total images 0 - 0.00s
# Process predict started for weather/3/2
# weather/snow/2 - Total images 0 - 0.01s
# Process predict started for weather/3/3
# weather/snow/3 - Total images 0 - 0.01s
# Process predict started for weather/3/4
# weather/snow/4 - Total images 0 - 0.01s
# Process predict started for weather/3/5
# weather/snow/5 - Total images 0 - 0.01s
# weather/snow/1 - Total images 1000 - 5.39s
# weather/snow/2 - Total images 1000 - 6.26s
# weather/snow/3 - Total images 1000 - 6.36s
# weather/snow/4 - Total images 1000 - 5.90s
# weather/snow/5 - Total images 1000 - 6.12s
# weather/snow/1 - Total images 2000 - 11.41s
# weather/snow/2 - Total images 2000 - 12.02s
# weather/snow/5 - Total images 2000 - 11.72s
# weather/snow/3 - Total images 2000 - 12.87s
# weather/snow/4 - Total images 2000 - 12.32s
# weather/snow/1 - Total images 3000 - 17.74s
# weather/snow/2 - Total images 3000 - 17.90s
# weather/snow/5 - Total images 3000 - 17.74s
# weather/snow/3 - Total images 3000 - 18.87s
# weather/snow/4 - Total images 3000 - 18.50s
# weather/snow/2 - Total images 4000 - 23.43s
# weather/snow/1 - Total images 4000 - 24.07s
# weather/snow/5 - Total images 4000 - 23.74s
# weather/snow/3 - Total images 4000 - 24.98s
# weather/snow/4 - Total images 4000 - 25.02s
# weather/snow/1 - Total images 5000 - 29.73s
# weather/snow/2 - Total images 5000 - 29.70s
# weather/snow/5 - Total images 5000 - 29.83s
# weather/snow/3 - Total images 5000 - 31.39s
# weather/snow/4 - Total images 5000 - 31.03s
# weather/snow/1 - Total images 6000 - 36.37s
# weather/snow/2 - Total images 6000 - 36.18s
# weather/snow/5 - Total images 6000 - 35.23s
# weather/snow/4 - Total images 6000 - 36.51s
# weather/snow/3 - Total images 6000 - 37.85s
# weather/snow/5 - Total images 7000 - 40.65s
# weather/snow/1 - Total images 7000 - 43.06s
# weather/snow/2 - Total images 7000 - 42.74s
# weather/snow/4 - Total images 7000 - 42.24s
# weather/snow/3 - Total images 7000 - 44.29s
# weather/snow/2 - Total images 8000 - 48.52s
# weather/snow/5 - Total images 8000 - 47.12s
# weather/snow/1 - Total images 8000 - 49.38s
# weather/snow/4 - Total images 8000 - 48.72s
# weather/snow/3 - Total images 8000 - 49.82s
# weather/snow/2 - Total images 9000 - 54.11s
# weather/snow/5 - Total images 9000 - 53.59s
# weather/snow/1 - Total images 9000 - 55.97s
# weather/snow/3 - Total images 9000 - 55.31s
# weather/snow/4 - Total images 9000 - 55.26s
# weather/snow/2 - Total images 10000 - 60.35s
# weather/snow/1 - Total images 10000 - 61.68s
# weather/snow/5 - Total images 10000 - 59.99s
# weather/snow/3 - Total images 10000 - 61.15s
# weather/snow/4 - Total images 10000 - 61.02s
# File save with success!
# /content/drive/MyDrive/Mestrado/Robustness/optimization/mobilenet_v2/results/ce_mobilenet_v2_qat_full_integer.json
# clean - Total images 0 - 0.01s
# clean - Total images 1000 - 7.13s
# clean - Total images 2000 - 14.26s
# clean - Total images 3000 - 21.32s
# clean - Total images 4000 - 28.30s
# clean - Total images 5000 - 35.30s
# clean - Total images 6000 - 42.22s
# clean - Total images 7000 - 49.21s
# clean - Total images 8000 - 56.27s
# clean - Total images 9000 - 63.38s
# clean - Total images 10000 - 70.47s
# Accuracy for clean is 0.7954
# Process predict started for blur/0/1
# blur/defocus_blur/1 - Total images 0 - 0.01s
# Process predict started for blur/0/2
# blur/defocus_blur/2 - Total images 0 - 0.01s
# Process predict started for blur/0/3
# blur/defocus_blur/3 - Total images 0 - 0.01s
# Process predict started for blur/0/4
# blur/defocus_blur/4 - Total images 0 - 0.01s
# Process predict started for blur/0/5
# blur/defocus_blur/5 - Total images 0 - 0.01s
# blur/defocus_blur/1 - Total images 1000 - 9.50s
# blur/defocus_blur/2 - Total images 1000 - 10.11s
# blur/defocus_blur/3 - Total images 1000 - 9.98s
# blur/defocus_blur/4 - Total images 1000 - 10.71s
# blur/defocus_blur/5 - Total images 1000 - 10.41s
# blur/defocus_blur/1 - Total images 2000 - 19.44s
# blur/defocus_blur/2 - Total images 2000 - 20.09s
# blur/defocus_blur/3 - Total images 2000 - 20.88s
# blur/defocus_blur/5 - Total images 2000 - 20.29s
# blur/defocus_blur/4 - Total images 2000 - 21.20s
# blur/defocus_blur/1 - Total images 3000 - 29.43s
# blur/defocus_blur/2 - Total images 3000 - 30.18s
# blur/defocus_blur/5 - Total images 3000 - 30.59s
# blur/defocus_blur/3 - Total images 3000 - 31.69s
# blur/defocus_blur/4 - Total images 3000 - 31.62s
# blur/defocus_blur/1 - Total images 4000 - 40.14s
# blur/defocus_blur/2 - Total images 4000 - 40.15s
# blur/defocus_blur/5 - Total images 4000 - 40.28s
# blur/defocus_blur/3 - Total images 4000 - 41.93s
# blur/defocus_blur/4 - Total images 4000 - 42.44s
# blur/defocus_blur/1 - Total images 5000 - 51.03s
# blur/defocus_blur/2 - Total images 5000 - 50.74s
# blur/defocus_blur/5 - Total images 5000 - 49.99s
# blur/defocus_blur/3 - Total images 5000 - 51.29s
# blur/defocus_blur/4 - Total images 5000 - 53.08s
# blur/defocus_blur/2 - Total images 6000 - 60.45s
# blur/defocus_blur/3 - Total images 6000 - 60.81s
# blur/defocus_blur/1 - Total images 6000 - 61.82s
# blur/defocus_blur/5 - Total images 6000 - 60.87s
# blur/defocus_blur/4 - Total images 6000 - 63.97s
# blur/defocus_blur/2 - Total images 7000 - 70.42s
# blur/defocus_blur/3 - Total images 7000 - 70.50s
# blur/defocus_blur/1 - Total images 7000 - 72.53s
# blur/defocus_blur/5 - Total images 7000 - 71.25s
# blur/defocus_blur/4 - Total images 7000 - 74.58s
# blur/defocus_blur/3 - Total images 8000 - 79.36s
# blur/defocus_blur/2 - Total images 8000 - 80.95s
# blur/defocus_blur/1 - Total images 8000 - 82.89s
# blur/defocus_blur/5 - Total images 8000 - 81.82s
# blur/defocus_blur/4 - Total images 8000 - 84.46s
# blur/defocus_blur/3 - Total images 9000 - 89.61s
# blur/defocus_blur/2 - Total images 9000 - 91.91s
# blur/defocus_blur/1 - Total images 9000 - 92.55s
# blur/defocus_blur/5 - Total images 9000 - 92.80s
# blur/defocus_blur/4 - Total images 9000 - 94.53s
# blur/defocus_blur/3 - Total images 10000 - 100.40s
# blur/defocus_blur/2 - Total images 10000 - 102.30s
# blur/defocus_blur/1 - Total images 10000 - 102.83s
# blur/defocus_blur/4 - Total images 10000 - 102.78s
# blur/defocus_blur/5 - Total images 10000 - 102.28s
# File save with success!
# Process predict started for blur/1/1
# blur/glass_blur/1 - Total images 0 - 0.01s
# Process predict started for blur/1/2
# blur/glass_blur/2 - Total images 0 - 0.01s
# Process predict started for blur/1/3
# blur/glass_blur/3 - Total images 0 - 0.01s
# Process predict started for blur/1/4
# blur/glass_blur/4 - Total images 0 - 0.01s
# Process predict started for blur/1/5
# blur/glass_blur/5 - Total images 0 - 0.01s
# blur/glass_blur/1 - Total images 1000 - 10.08s
# blur/glass_blur/2 - Total images 1000 - 10.21s
# blur/glass_blur/3 - Total images 1000 - 10.40s
# blur/glass_blur/4 - Total images 1000 - 10.17s
# blur/glass_blur/5 - Total images 1000 - 9.91s
# blur/glass_blur/1 - Total images 2000 - 20.66s
# blur/glass_blur/2 - Total images 2000 - 20.57s
# blur/glass_blur/5 - Total images 2000 - 19.72s
# blur/glass_blur/4 - Total images 2000 - 20.31s
# blur/glass_blur/3 - Total images 2000 - 21.07s
# blur/glass_blur/1 - Total images 3000 - 30.29s
# blur/glass_blur/5 - Total images 3000 - 29.89s
# blur/glass_blur/2 - Total images 3000 - 31.38s
# blur/glass_blur/3 - Total images 3000 - 31.15s
# blur/glass_blur/4 - Total images 3000 - 31.33s
# blur/glass_blur/1 - Total images 4000 - 40.38s
# blur/glass_blur/2 - Total images 4000 - 41.45s
# blur/glass_blur/5 - Total images 4000 - 40.36s
# blur/glass_blur/3 - Total images 4000 - 41.48s
# blur/glass_blur/4 - Total images 4000 - 42.24s
# blur/glass_blur/1 - Total images 5000 - 50.89s
# blur/glass_blur/2 - Total images 5000 - 51.45s
# blur/glass_blur/5 - Total images 5000 - 50.61s
# blur/glass_blur/3 - Total images 5000 - 51.88s
# blur/glass_blur/4 - Total images 5000 - 52.51s
# blur/glass_blur/2 - Total images 6000 - 61.08s
# blur/glass_blur/1 - Total images 6000 - 61.90s
# blur/glass_blur/5 - Total images 6000 - 60.98s
# blur/glass_blur/3 - Total images 6000 - 62.70s
# blur/glass_blur/4 - Total images 6000 - 62.79s
# blur/glass_blur/2 - Total images 7000 - 70.65s
# blur/glass_blur/5 - Total images 7000 - 70.46s
# blur/glass_blur/1 - Total images 7000 - 72.87s
# blur/glass_blur/3 - Total images 7000 - 73.52s
# blur/glass_blur/4 - Total images 7000 - 73.76s
# blur/glass_blur/2 - Total images 8000 - 81.07s
# blur/glass_blur/5 - Total images 8000 - 79.88s
# blur/glass_blur/1 - Total images 8000 - 83.89s
# blur/glass_blur/4 - Total images 8000 - 83.97s
# blur/glass_blur/3 - Total images 8000 - 84.45s
# blur/glass_blur/5 - Total images 9000 - 88.71s
# blur/glass_blur/2 - Total images 9000 - 91.95s
# blur/glass_blur/1 - Total images 9000 - 94.49s
# blur/glass_blur/4 - Total images 9000 - 94.13s
# blur/glass_blur/3 - Total images 9000 - 94.94s
# blur/glass_blur/5 - Total images 10000 - 97.07s
# blur/glass_blur/2 - Total images 10000 - 102.83s
# blur/glass_blur/3 - Total images 10000 - 103.36s
# blur/glass_blur/1 - Total images 10000 - 104.49s
# blur/glass_blur/4 - Total images 10000 - 103.86s
# File save with success!
# Process predict started for blur/2/1
# blur/motion_blur/1 - Total images 0 - 0.01s
# Process predict started for blur/2/2
# blur/motion_blur/2 - Total images 0 - 0.01s
# Process predict started for blur/2/3
# blur/motion_blur/3 - Total images 0 - 0.01s
# Process predict started for blur/2/4
# blur/motion_blur/4 - Total images 0 - 0.01s
# Process predict started for blur/2/5
# blur/motion_blur/5 - Total images 0 - 0.01s
# blur/motion_blur/2 - Total images 1000 - 9.12s
# blur/motion_blur/3 - Total images 1000 - 9.32s
# blur/motion_blur/1 - Total images 1000 - 10.11s
# blur/motion_blur/4 - Total images 1000 - 10.67s
# blur/motion_blur/5 - Total images 1000 - 10.54s
# blur/motion_blur/1 - Total images 2000 - 19.78s
# blur/motion_blur/3 - Total images 2000 - 19.23s
# blur/motion_blur/2 - Total images 2000 - 19.91s
# blur/motion_blur/4 - Total images 2000 - 21.37s
# blur/motion_blur/5 - Total images 2000 - 20.93s
# blur/motion_blur/3 - Total images 3000 - 29.46s
# blur/motion_blur/1 - Total images 3000 - 30.57s
# blur/motion_blur/2 - Total images 3000 - 30.53s
# blur/motion_blur/5 - Total images 3000 - 30.05s
# blur/motion_blur/4 - Total images 3000 - 31.94s
# blur/motion_blur/3 - Total images 4000 - 38.02s
# blur/motion_blur/1 - Total images 4000 - 41.24s
# blur/motion_blur/2 - Total images 4000 - 41.00s
# blur/motion_blur/5 - Total images 4000 - 40.67s
# blur/motion_blur/4 - Total images 4000 - 42.70s
# blur/motion_blur/3 - Total images 5000 - 47.02s
# blur/motion_blur/2 - Total images 5000 - 51.63s
# blur/motion_blur/1 - Total images 5000 - 52.17s
# blur/motion_blur/5 - Total images 5000 - 50.81s
# blur/motion_blur/4 - Total images 5000 - 53.03s
# blur/motion_blur/3 - Total images 6000 - 56.85s
# blur/motion_blur/2 - Total images 6000 - 61.90s
# blur/motion_blur/5 - Total images 6000 - 61.19s
# blur/motion_blur/1 - Total images 6000 - 63.07s
# blur/motion_blur/4 - Total images 6000 - 63.48s
# blur/motion_blur/3 - Total images 7000 - 66.99s
# blur/motion_blur/2 - Total images 7000 - 71.64s
# blur/motion_blur/5 - Total images 7000 - 71.09s
# blur/motion_blur/1 - Total images 7000 - 73.70s
# blur/motion_blur/4 - Total images 7000 - 74.26s
# blur/motion_blur/3 - Total images 8000 - 77.22s
# blur/motion_blur/2 - Total images 8000 - 81.79s
# blur/motion_blur/5 - Total images 8000 - 80.61s
# blur/motion_blur/1 - Total images 8000 - 84.43s
# blur/motion_blur/4 - Total images 8000 - 84.30s
# blur/motion_blur/3 - Total images 9000 - 87.46s
# blur/motion_blur/2 - Total images 9000 - 92.36s
# blur/motion_blur/5 - Total images 9000 - 91.52s
# blur/motion_blur/1 - Total images 9000 - 93.88s
# blur/motion_blur/4 - Total images 9000 - 93.90s
# blur/motion_blur/3 - Total images 10000 - 97.89s
# blur/motion_blur/5 - Total images 10000 - 100.32s
# blur/motion_blur/2 - Total images 10000 - 102.63s
# blur/motion_blur/1 - Total images 10000 - 103.38s
# blur/motion_blur/4 - Total images 10000 - 103.01s
# File save with success!
# Process predict started for blur/3/1
# blur/zoom_blur/1 - Total images 0 - 0.01s
# Process predict started for blur/3/2
# blur/zoom_blur/2 - Total images 0 - 0.01s
# Process predict started for blur/3/3
# blur/zoom_blur/3 - Total images 0 - 0.01s
# Process predict started for blur/3/4
# blur/zoom_blur/4 - Total images 0 - 0.01s
# Process predict started for blur/3/5
# blur/zoom_blur/5 - Total images 0 - 0.01s
# blur/zoom_blur/1 - Total images 1000 - 9.49s
# blur/zoom_blur/2 - Total images 1000 - 10.08s
# blur/zoom_blur/4 - Total images 1000 - 9.92s
# blur/zoom_blur/3 - Total images 1000 - 10.56s
# blur/zoom_blur/5 - Total images 1000 - 10.86s
# blur/zoom_blur/1 - Total images 2000 - 19.12s
# blur/zoom_blur/2 - Total images 2000 - 20.44s
# blur/zoom_blur/4 - Total images 2000 - 19.73s
# blur/zoom_blur/3 - Total images 2000 - 21.09s
# blur/zoom_blur/5 - Total images 2000 - 21.33s
# blur/zoom_blur/1 - Total images 3000 - 29.65s
# blur/zoom_blur/2 - Total images 3000 - 31.03s
# blur/zoom_blur/4 - Total images 3000 - 30.21s
# blur/zoom_blur/3 - Total images 3000 - 31.02s
# blur/zoom_blur/5 - Total images 3000 - 30.97s
# blur/zoom_blur/1 - Total images 4000 - 40.44s
# blur/zoom_blur/4 - Total images 4000 - 40.16s
# blur/zoom_blur/3 - Total images 4000 - 41.05s
# blur/zoom_blur/2 - Total images 4000 - 41.76s
# blur/zoom_blur/5 - Total images 4000 - 41.01s
# blur/zoom_blur/1 - Total images 5000 - 51.23s
# blur/zoom_blur/4 - Total images 5000 - 50.08s
# blur/zoom_blur/3 - Total images 5000 - 51.42s
# blur/zoom_blur/5 - Total images 5000 - 50.81s
# blur/zoom_blur/2 - Total images 5000 - 52.49s
# blur/zoom_blur/1 - Total images 6000 - 61.78s
# blur/zoom_blur/5 - Total images 6000 - 60.22s
# blur/zoom_blur/4 - Total images 6000 - 60.96s
# blur/zoom_blur/2 - Total images 6000 - 62.25s
# blur/zoom_blur/3 - Total images 6000 - 62.13s
# blur/zoom_blur/5 - Total images 7000 - 68.74s
# blur/zoom_blur/3 - Total images 7000 - 71.91s
# blur/zoom_blur/1 - Total images 7000 - 72.69s
# blur/zoom_blur/4 - Total images 7000 - 71.81s
# blur/zoom_blur/2 - Total images 7000 - 73.14s
# blur/zoom_blur/5 - Total images 8000 - 79.17s
# blur/zoom_blur/3 - Total images 8000 - 81.03s
# blur/zoom_blur/2 - Total images 8000 - 83.01s
# blur/zoom_blur/1 - Total images 8000 - 83.54s
# blur/zoom_blur/4 - Total images 8000 - 82.68s
# blur/zoom_blur/5 - Total images 9000 - 89.34s
# blur/zoom_blur/3 - Total images 9000 - 90.78s
# blur/zoom_blur/2 - Total images 9000 - 93.34s
# blur/zoom_blur/1 - Total images 9000 - 94.18s
# blur/zoom_blur/4 - Total images 9000 - 93.54s
# blur/zoom_blur/3 - Total images 10000 - 100.09s
# blur/zoom_blur/5 - Total images 10000 - 99.90s
# blur/zoom_blur/2 - Total images 10000 - 102.16s
# blur/zoom_blur/1 - Total images 10000 - 104.00s
# blur/zoom_blur/4 - Total images 10000 - 103.18s
# File save with success!
# Process predict started for digital/0/1
# digital/contrast/1 - Total images 0 - 0.01s
# Process predict started for digital/0/2
# digital/contrast/2 - Total images 0 - 0.01s
# Process predict started for digital/0/3
# digital/contrast/3 - Total images 0 - 0.01s
# Process predict started for digital/0/4
# digital/contrast/4 - Total images 0 - 0.01s
# Process predict started for digital/0/5
# digital/contrast/5 - Total images 0 - 0.01s
# digital/contrast/1 - Total images 1000 - 10.13s
# digital/contrast/3 - Total images 1000 - 9.89s
# digital/contrast/2 - Total images 1000 - 10.48s
# digital/contrast/4 - Total images 1000 - 10.44s
# digital/contrast/5 - Total images 1000 - 10.10s
# digital/contrast/1 - Total images 2000 - 19.86s
# digital/contrast/2 - Total images 2000 - 19.96s
# digital/contrast/3 - Total images 2000 - 20.57s
# digital/contrast/4 - Total images 2000 - 21.34s
# digital/contrast/5 - Total images 2000 - 21.04s
# digital/contrast/1 - Total images 3000 - 30.36s
# digital/contrast/2 - Total images 3000 - 30.38s
# digital/contrast/3 - Total images 3000 - 30.49s
# digital/contrast/5 - Total images 3000 - 30.89s
# digital/contrast/4 - Total images 3000 - 32.01s
# digital/contrast/1 - Total images 4000 - 40.20s
# digital/contrast/2 - Total images 4000 - 40.75s
# digital/contrast/3 - Total images 4000 - 40.84s
# digital/contrast/5 - Total images 4000 - 40.94s
# digital/contrast/4 - Total images 4000 - 42.54s
# digital/contrast/3 - Total images 5000 - 50.31s
# digital/contrast/1 - Total images 5000 - 51.15s
# digital/contrast/2 - Total images 5000 - 51.22s
# digital/contrast/5 - Total images 5000 - 51.74s
# digital/contrast/4 - Total images 5000 - 52.71s
# digital/contrast/2 - Total images 6000 - 60.77s
# digital/contrast/3 - Total images 6000 - 60.77s
# digital/contrast/1 - Total images 6000 - 62.08s
# digital/contrast/5 - Total images 6000 - 61.68s
# digital/contrast/4 - Total images 6000 - 63.32s
# digital/contrast/2 - Total images 7000 - 70.45s
# digital/contrast/3 - Total images 7000 - 70.96s
# digital/contrast/1 - Total images 7000 - 72.49s
# digital/contrast/5 - Total images 7000 - 72.22s
# digital/contrast/4 - Total images 7000 - 74.05s
# digital/contrast/2 - Total images 8000 - 80.24s
# digital/contrast/3 - Total images 8000 - 81.03s
# digital/contrast/1 - Total images 8000 - 83.35s
# digital/contrast/5 - Total images 8000 - 81.89s
# digital/contrast/4 - Total images 8000 - 84.53s
# digital/contrast/2 - Total images 9000 - 90.99s
# digital/contrast/3 - Total images 9000 - 91.74s
# digital/contrast/5 - Total images 9000 - 91.16s
# digital/contrast/1 - Total images 9000 - 93.12s
# digital/contrast/4 - Total images 9000 - 95.00s
# digital/contrast/2 - Total images 10000 - 101.30s
# digital/contrast/3 - Total images 10000 - 101.27s
# digital/contrast/5 - Total images 10000 - 101.29s
# digital/contrast/1 - Total images 10000 - 103.13s
# digital/contrast/4 - Total images 10000 - 104.18s
# File save with success!
# Process predict started for digital/1/1
# digital/elastic_transform/1 - Total images 0 - 0.01s
# Process predict started for digital/1/2
# digital/elastic_transform/2 - Total images 0 - 0.01s
# Process predict started for digital/1/3
# digital/elastic_transform/3 - Total images 0 - 0.01s
# Process predict started for digital/1/4
# digital/elastic_transform/4 - Total images 0 - 0.01s
# Process predict started for digital/1/5
# digital/elastic_transform/5 - Total images 0 - 0.01s
# digital/elastic_transform/2 - Total images 1000 - 9.63s
# digital/elastic_transform/1 - Total images 1000 - 10.20s
# digital/elastic_transform/3 - Total images 1000 - 9.63s
# digital/elastic_transform/4 - Total images 1000 - 10.68s
# digital/elastic_transform/5 - Total images 1000 - 10.58s
# digital/elastic_transform/1 - Total images 2000 - 20.07s
# digital/elastic_transform/3 - Total images 2000 - 20.14s
# digital/elastic_transform/2 - Total images 2000 - 20.57s
# digital/elastic_transform/4 - Total images 2000 - 20.94s
# digital/elastic_transform/5 - Total images 2000 - 20.81s
# digital/elastic_transform/3 - Total images 3000 - 29.61s
# digital/elastic_transform/1 - Total images 3000 - 30.90s
# digital/elastic_transform/4 - Total images 3000 - 30.29s
# digital/elastic_transform/2 - Total images 3000 - 31.54s
# digital/elastic_transform/5 - Total images 3000 - 31.65s
# digital/elastic_transform/1 - Total images 4000 - 40.78s
# digital/elastic_transform/3 - Total images 4000 - 40.18s
# digital/elastic_transform/4 - Total images 4000 - 40.22s
# digital/elastic_transform/2 - Total images 4000 - 41.80s
# digital/elastic_transform/5 - Total images 4000 - 42.20s
# digital/elastic_transform/3 - Total images 5000 - 49.77s
# digital/elastic_transform/1 - Total images 5000 - 51.04s
# digital/elastic_transform/4 - Total images 5000 - 50.60s
# digital/elastic_transform/2 - Total images 5000 - 52.38s
# digital/elastic_transform/5 - Total images 5000 - 52.62s
# digital/elastic_transform/3 - Total images 6000 - 59.82s
# digital/elastic_transform/1 - Total images 6000 - 60.98s
# digital/elastic_transform/4 - Total images 6000 - 61.04s
# digital/elastic_transform/2 - Total images 6000 - 63.03s
# digital/elastic_transform/5 - Total images 6000 - 62.46s
# digital/elastic_transform/3 - Total images 7000 - 69.50s
# digital/elastic_transform/1 - Total images 7000 - 70.92s
# digital/elastic_transform/4 - Total images 7000 - 71.59s
# digital/elastic_transform/2 - Total images 7000 - 73.78s
# digital/elastic_transform/5 - Total images 7000 - 73.03s
# digital/elastic_transform/3 - Total images 8000 - 79.23s
# digital/elastic_transform/1 - Total images 8000 - 81.46s
# digital/elastic_transform/4 - Total images 8000 - 81.67s
# digital/elastic_transform/2 - Total images 8000 - 83.65s
# digital/elastic_transform/5 - Total images 8000 - 83.84s
# digital/elastic_transform/3 - Total images 9000 - 89.91s
# digital/elastic_transform/1 - Total images 9000 - 91.98s
# digital/elastic_transform/4 - Total images 9000 - 91.38s
# digital/elastic_transform/2 - Total images 9000 - 94.06s
# digital/elastic_transform/5 - Total images 9000 - 94.45s
# digital/elastic_transform/3 - Total images 10000 - 100.01s
# digital/elastic_transform/1 - Total images 10000 - 102.18s
# digital/elastic_transform/4 - Total images 10000 - 101.27s
# digital/elastic_transform/2 - Total images 10000 - 103.92s
# digital/elastic_transform/5 - Total images 10000 - 102.88s
# File save with success!
# Process predict started for digital/2/1
# digital/jpeg_compression/1 - Total images 0 - 0.01s
# Process predict started for digital/2/2
# digital/jpeg_compression/2 - Total images 0 - 0.01s
# Process predict started for digital/2/3
# digital/jpeg_compression/3 - Total images 0 - 0.01s
# Process predict started for digital/2/4
# digital/jpeg_compression/4 - Total images 0 - 0.01s
# Process predict started for digital/2/5
# digital/jpeg_compression/5 - Total images 0 - 0.01s
# digital/jpeg_compression/2 - Total images 1000 - 9.71s
# digital/jpeg_compression/3 - Total images 1000 - 9.62s
# digital/jpeg_compression/1 - Total images 1000 - 10.61s
# digital/jpeg_compression/4 - Total images 1000 - 10.93s
# digital/jpeg_compression/5 - Total images 1000 - 11.02s
# digital/jpeg_compression/1 - Total images 2000 - 20.36s
# digital/jpeg_compression/3 - Total images 2000 - 19.68s
# digital/jpeg_compression/2 - Total images 2000 - 20.18s
# digital/jpeg_compression/4 - Total images 2000 - 22.06s
# digital/jpeg_compression/5 - Total images 2000 - 22.16s
# digital/jpeg_compression/2 - Total images 3000 - 30.21s
# digital/jpeg_compression/3 - Total images 3000 - 30.24s
# digital/jpeg_compression/1 - Total images 3000 - 31.04s
# digital/jpeg_compression/4 - Total images 3000 - 32.30s
# digital/jpeg_compression/5 - Total images 3000 - 32.73s
# digital/jpeg_compression/1 - Total images 4000 - 41.09s
# digital/jpeg_compression/3 - Total images 4000 - 40.50s
# digital/jpeg_compression/2 - Total images 4000 - 41.27s
# digital/jpeg_compression/4 - Total images 4000 - 43.21s
# digital/jpeg_compression/5 - Total images 4000 - 43.30s
# digital/jpeg_compression/3 - Total images 5000 - 50.03s
# digital/jpeg_compression/1 - Total images 5000 - 51.63s
# digital/jpeg_compression/2 - Total images 5000 - 52.38s
# digital/jpeg_compression/4 - Total images 5000 - 53.50s
# digital/jpeg_compression/5 - Total images 5000 - 54.02s
# digital/jpeg_compression/1 - Total images 6000 - 61.33s
# digital/jpeg_compression/3 - Total images 6000 - 60.93s
# digital/jpeg_compression/2 - Total images 6000 - 62.45s
# digital/jpeg_compression/4 - Total images 6000 - 64.33s
# digital/jpeg_compression/5 - Total images 6000 - 65.17s
# digital/jpeg_compression/1 - Total images 7000 - 71.37s
# digital/jpeg_compression/3 - Total images 7000 - 71.94s
# digital/jpeg_compression/2 - Total images 7000 - 73.00s
# digital/jpeg_compression/4 - Total images 7000 - 74.36s
# digital/jpeg_compression/5 - Total images 7000 - 76.26s
# digital/jpeg_compression/1 - Total images 8000 - 80.83s
# digital/jpeg_compression/3 - Total images 8000 - 82.98s
# digital/jpeg_compression/2 - Total images 8000 - 83.67s
# digital/jpeg_compression/4 - Total images 8000 - 85.07s
# digital/jpeg_compression/5 - Total images 8000 - 85.97s
# digital/jpeg_compression/1 - Total images 9000 - 91.39s
# digital/jpeg_compression/2 - Total images 9000 - 93.78s
# digital/jpeg_compression/3 - Total images 9000 - 93.92s
# digital/jpeg_compression/4 - Total images 9000 - 95.66s
# digital/jpeg_compression/5 - Total images 9000 - 96.03s
# digital/jpeg_compression/1 - Total images 10000 - 101.83s
# digital/jpeg_compression/2 - Total images 10000 - 103.10s
# digital/jpeg_compression/3 - Total images 10000 - 103.53s
# digital/jpeg_compression/4 - Total images 10000 - 105.13s
# digital/jpeg_compression/5 - Total images 10000 - 105.18s
# File save with success!
# Process predict started for digital/3/1
# digital/pixelate/1 - Total images 0 - 0.01s
# Process predict started for digital/3/2
# digital/pixelate/2 - Total images 0 - 0.01s
# Process predict started for digital/3/3
# digital/pixelate/3 - Total images 0 - 0.01s
# Process predict started for digital/3/4
# digital/pixelate/4 - Total images 0 - 0.01s
# Process predict started for digital/3/5
# digital/pixelate/5 - Total images 0 - 0.01s
# digital/pixelate/1 - Total images 1000 - 9.08s
# digital/pixelate/4 - Total images 1000 - 9.57s
# digital/pixelate/2 - Total images 1000 - 10.59s
# digital/pixelate/3 - Total images 1000 - 10.88s
# digital/pixelate/5 - Total images 1000 - 11.08s
# digital/pixelate/1 - Total images 2000 - 19.34s
# digital/pixelate/2 - Total images 2000 - 20.58s
# digital/pixelate/4 - Total images 2000 - 20.10s
# digital/pixelate/3 - Total images 2000 - 21.89s
# digital/pixelate/5 - Total images 2000 - 21.11s
# digital/pixelate/1 - Total images 3000 - 29.86s
# digital/pixelate/2 - Total images 3000 - 30.33s
# digital/pixelate/4 - Total images 3000 - 29.87s
# digital/pixelate/3 - Total images 3000 - 32.26s
# digital/pixelate/5 - Total images 3000 - 31.64s
# digital/pixelate/1 - Total images 4000 - 40.46s
# digital/pixelate/3 - Total images 4000 - 40.76sdigital/pixelate/2 - Total images 4000 - 41.15s
#
# digital/pixelate/4 - Total images 4000 - 40.40s
# digital/pixelate/5 - Total images 4000 - 42.58s
# digital/pixelate/1 - Total images 5000 - 50.07s
# digital/pixelate/4 - Total images 5000 - 50.30s
# digital/pixelate/2 - Total images 5000 - 51.38s
# digital/pixelate/3 - Total images 5000 - 51.58s
# digital/pixelate/5 - Total images 5000 - 53.31s
# digital/pixelate/1 - Total images 6000 - 60.65s
# digital/pixelate/4 - Total images 6000 - 60.28s
# digital/pixelate/2 - Total images 6000 - 61.36s
# digital/pixelate/3 - Total images 6000 - 62.18s
# digital/pixelate/5 - Total images 6000 - 63.87s
# digital/pixelate/1 - Total images 7000 - 71.40s
# digital/pixelate/4 - Total images 7000 - 70.35s
# digital/pixelate/2 - Total images 7000 - 71.37s
# digital/pixelate/3 - Total images 7000 - 73.12s
# digital/pixelate/5 - Total images 7000 - 73.68s
# digital/pixelate/4 - Total images 8000 - 79.83s
# digital/pixelate/1 - Total images 8000 - 82.14s
# digital/pixelate/2 - Total images 8000 - 82.31s
# digital/pixelate/3 - Total images 8000 - 84.21s
# digital/pixelate/5 - Total images 8000 - 83.49s
# digital/pixelate/4 - Total images 9000 - 90.27s
# digital/pixelate/1 - Total images 9000 - 92.37s
# digital/pixelate/2 - Total images 9000 - 92.35s
# digital/pixelate/5 - Total images 9000 - 93.35s
# digital/pixelate/3 - Total images 9000 - 95.16s
# digital/pixelate/4 - Total images 10000 - 101.05s
# digital/pixelate/1 - Total images 10000 - 102.59s
# digital/pixelate/2 - Total images 10000 - 102.33s
# digital/pixelate/5 - Total images 10000 - 102.59s
# digital/pixelate/3 - Total images 10000 - 104.67s
# File save with success!
# Process predict started for noise/0/1
# noise/gaussian_noise/1 - Total images 0 - 0.01s
# Process predict started for noise/0/2
# noise/gaussian_noise/2 - Total images 0 - 0.01s
# Process predict started for noise/0/3
# noise/gaussian_noise/3 - Total images 0 - 0.01s
# Process predict started for noise/0/4
# noise/gaussian_noise/4 - Total images 0 - 0.01s
# Process predict started for noise/0/5
# noise/gaussian_noise/5 - Total images 0 - 0.01s
# noise/gaussian_noise/1 - Total images 1000 - 10.02s
# noise/gaussian_noise/2 - Total images 1000 - 10.34s
# noise/gaussian_noise/3 - Total images 1000 - 10.54s
# noise/gaussian_noise/4 - Total images 1000 - 10.30s
# noise/gaussian_noise/5 - Total images 1000 - 10.63s
# noise/gaussian_noise/1 - Total images 2000 - 20.34s
# noise/gaussian_noise/3 - Total images 2000 - 20.40s
# noise/gaussian_noise/2 - Total images 2000 - 20.99s
# noise/gaussian_noise/4 - Total images 2000 - 21.12s
# noise/gaussian_noise/5 - Total images 2000 - 21.46s
# noise/gaussian_noise/3 - Total images 3000 - 29.67s
# noise/gaussian_noise/1 - Total images 3000 - 31.29s
# noise/gaussian_noise/4 - Total images 3000 - 31.02s
# noise/gaussian_noise/2 - Total images 3000 - 31.86s
# noise/gaussian_noise/5 - Total images 3000 - 32.08s
# noise/gaussian_noise/3 - Total images 4000 - 39.52s
# noise/gaussian_noise/4 - Total images 4000 - 40.61s
# noise/gaussian_noise/1 - Total images 4000 - 42.39s
# noise/gaussian_noise/2 - Total images 4000 - 42.84s
# noise/gaussian_noise/5 - Total images 4000 - 42.66s
# noise/gaussian_noise/3 - Total images 5000 - 49.18s
# noise/gaussian_noise/4 - Total images 5000 - 50.34s
# noise/gaussian_noise/1 - Total images 5000 - 53.38s
# noise/gaussian_noise/2 - Total images 5000 - 53.56s
# noise/gaussian_noise/5 - Total images 5000 - 53.24s
# noise/gaussian_noise/3 - Total images 6000 - 59.41s
# noise/gaussian_noise/4 - Total images 6000 - 60.72s
# noise/gaussian_noise/2 - Total images 6000 - 63.27s
# noise/gaussian_noise/1 - Total images 6000 - 63.91s
# noise/gaussian_noise/5 - Total images 6000 - 63.68s
# noise/gaussian_noise/3 - Total images 7000 - 70.27s
# noise/gaussian_noise/4 - Total images 7000 - 71.30s
# noise/gaussian_noise/2 - Total images 7000 - 72.81s
# noise/gaussian_noise/1 - Total images 7000 - 74.89s
# noise/gaussian_noise/5 - Total images 7000 - 73.26s
# noise/gaussian_noise/3 - Total images 8000 - 80.99s
# noise/gaussian_noise/4 - Total images 8000 - 81.73s
# noise/gaussian_noise/2 - Total images 8000 - 83.55s
# noise/gaussian_noise/1 - Total images 8000 - 85.09s
# noise/gaussian_noise/5 - Total images 8000 - 84.08s
# noise/gaussian_noise/3 - Total images 9000 - 91.14s
# noise/gaussian_noise/4 - Total images 9000 - 92.14s
# noise/gaussian_noise/1 - Total images 9000 - 94.83s
# noise/gaussian_noise/2 - Total images 9000 - 94.65s
# noise/gaussian_noise/5 - Total images 9000 - 94.97s
# noise/gaussian_noise/3 - Total images 10000 - 100.78s
# noise/gaussian_noise/4 - Total images 10000 - 101.46s
# noise/gaussian_noise/1 - Total images 10000 - 104.65s
# noise/gaussian_noise/2 - Total images 10000 - 104.87s
# noise/gaussian_noise/5 - Total images 10000 - 104.60s
# File save with success!
# Process predict started for noise/1/1
# noise/impulse_noise/1 - Total images 0 - 0.01s
# Process predict started for noise/1/2
# noise/impulse_noise/2 - Total images 0 - 0.01s
# Process predict started for noise/1/3
# noise/impulse_noise/3 - Total images 0 - 0.01s
# Process predict started for noise/1/4
# noise/impulse_noise/4 - Total images 0 - 0.01s
# Process predict started for noise/1/5
# noise/impulse_noise/5 - Total images 0 - 0.01s
# noise/impulse_noise/1 - Total images 1000 - 9.37s
# noise/impulse_noise/2 - Total images 1000 - 10.47s
# noise/impulse_noise/3 - Total images 1000 - 10.27s
# noise/impulse_noise/5 - Total images 1000 - 9.99s
# noise/impulse_noise/4 - Total images 1000 - 10.85s
# noise/impulse_noise/1 - Total images 2000 - 19.46s
# noise/impulse_noise/4 - Total images 2000 - 20.37s
# noise/impulse_noise/2 - Total images 2000 - 21.41s
# noise/impulse_noise/3 - Total images 2000 - 21.13s
# noise/impulse_noise/5 - Total images 2000 - 20.40s
# noise/impulse_noise/1 - Total images 3000 - 29.19s
# noise/impulse_noise/3 - Total images 3000 - 31.25s
# noise/impulse_noise/4 - Total images 3000 - 30.92s
# noise/impulse_noise/2 - Total images 3000 - 31.96s
# noise/impulse_noise/5 - Total images 3000 - 30.81s
# noise/impulse_noise/1 - Total images 4000 - 38.95s
# noise/impulse_noise/4 - Total images 4000 - 40.95s
# noise/impulse_noise/3 - Total images 4000 - 41.70s
# noise/impulse_noise/2 - Total images 4000 - 42.17s
# noise/impulse_noise/5 - Total images 4000 - 41.58s
# noise/impulse_noise/1 - Total images 5000 - 49.67s
# noise/impulse_noise/4 - Total images 5000 - 50.69s
# noise/impulse_noise/3 - Total images 5000 - 51.60s
# noise/impulse_noise/2 - Total images 5000 - 52.85s
# noise/impulse_noise/5 - Total images 5000 - 52.40s
# noise/impulse_noise/1 - Total images 6000 - 59.36s
# noise/impulse_noise/4 - Total images 6000 - 60.25s
# noise/impulse_noise/3 - Total images 6000 - 62.44s
# noise/impulse_noise/2 - Total images 6000 - 63.78s
# noise/impulse_noise/5 - Total images 6000 - 62.83s
# noise/impulse_noise/1 - Total images 7000 - 69.32s
# noise/impulse_noise/4 - Total images 7000 - 70.63s
# noise/impulse_noise/3 - Total images 7000 - 73.26s
# noise/impulse_noise/5 - Total images 7000 - 72.24s
# noise/impulse_noise/2 - Total images 7000 - 74.60s
# noise/impulse_noise/1 - Total images 8000 - 77.61s
# noise/impulse_noise/4 - Total images 8000 - 81.15s
# noise/impulse_noise/3 - Total images 8000 - 83.83s
# noise/impulse_noise/5 - Total images 8000 - 83.18s
# noise/impulse_noise/2 - Total images 8000 - 85.41s
# noise/impulse_noise/1 - Total images 9000 - 86.15s
# noise/impulse_noise/4 - Total images 9000 - 92.07s
# noise/impulse_noise/1 - Total images 10000 - 95.09s
# noise/impulse_noise/5 - Total images 9000 - 93.33s
# noise/impulse_noise/3 - Total images 9000 - 94.69s
# noise/impulse_noise/2 - Total images 9000 - 95.94s
# noise/impulse_noise/5 - Total images 10000 - 100.68s
# noise/impulse_noise/4 - Total images 10000 - 101.57s
# noise/impulse_noise/3 - Total images 10000 - 103.44s
# noise/impulse_noise/2 - Total images 10000 - 105.06s
# File save with success!
# Process predict started for noise/2/1
# noise/shot_noise/1 - Total images 0 - 0.01s
# Process predict started for noise/2/2
# noise/shot_noise/2 - Total images 0 - 0.01s
# Process predict started for noise/2/3
# noise/shot_noise/3 - Total images 0 - 0.01s
# Process predict started for noise/2/4
# noise/shot_noise/4 - Total images 0 - 0.01s
# Process predict started for noise/2/5
# noise/shot_noise/5 - Total images 0 - 0.01s
# noise/shot_noise/1 - Total images 1000 - 8.78s
# noise/shot_noise/3 - Total images 1000 - 9.78s
# noise/shot_noise/2 - Total images 1000 - 10.43s
# noise/shot_noise/4 - Total images 1000 - 10.78s
# noise/shot_noise/5 - Total images 1000 - 11.01s
# noise/shot_noise/1 - Total images 2000 - 18.46s
# noise/shot_noise/3 - Total images 2000 - 19.77s
# noise/shot_noise/2 - Total images 2000 - 20.80s
# noise/shot_noise/4 - Total images 2000 - 21.63s
# noise/shot_noise/5 - Total images 2000 - 21.63s
# noise/shot_noise/1 - Total images 3000 - 28.18s
# noise/shot_noise/2 - Total images 3000 - 30.54s
# noise/shot_noise/3 - Total images 3000 - 30.28s
# noise/shot_noise/4 - Total images 3000 - 32.28s
# noise/shot_noise/5 - Total images 3000 - 32.19s
# noise/shot_noise/1 - Total images 4000 - 39.00s
# noise/shot_noise/3 - Total images 4000 - 39.60s
# noise/shot_noise/2 - Total images 4000 - 40.05s
# noise/shot_noise/4 - Total images 4000 - 42.82s
# ...
# noise/impulse_noise/2 - Total images 2000 - 10.58s
# noise/impulse_noise/1 - Total images 2000 - 12.37s
# noise/impulse_noise/3 - Total images 2000 - 12.30s
# noise/impulse_noise/5 - Total images 2000 - 12.47s
# noise/impulse_noise/4 - Total images 2000 - 13.03s
# noise/impulse_noise/2 - Total images 3000 - 16.46s
# noise/impulse_noise/1 - Total images 3000 - 18.68s
# noise/impulse_noise/3 - Total images 3000 - 18.06s
# noise/impulse_noise/4 - Total images 3000 - 19.08s
# noise/impulse_noise/5 - Total images 3000 - 18.75s
# noise/impulse_noise/2 - Total images 4000 - 22.62s
# noise/impulse_noise/3 - Total images 4000 - 23.35s
# noise/impulse_noise/1 - Total images 4000 - 24.76s
# noise/impulse_noise/4 - Total images 4000 - 25.30s
# noise/impulse_noise/5 - Total images 4000 - 25.24s
# noise/impulse_noise/2 - Total images 5000 - 28.88s
# noise/impulse_noise/3 - Total images 5000 - 28.88s
# noise/impulse_noise/1 - Total images 5000 - 30.47s
# noise/impulse_noise/4 - Total images 5000 - 31.58s
# noise/impulse_noise/5 - Total images 5000 - 31.53s
# noise/impulse_noise/3 - Total images 6000 - 34.84s
# noise/impulse_noise/2 - Total images 6000 - 35.41s
# noise/impulse_noise/1 - Total images 6000 - 36.24s
# noise/impulse_noise/4 - Total images 6000 - 37.57s
# noise/impulse_noise/5 - Total images 6000 - 37.79s
# noise/impulse_noise/2 - Total images 7000 - 41.27s
# noise/impulse_noise/3 - Total images 7000 - 40.94s
# noise/impulse_noise/1 - Total images 7000 - 42.08s
# noise/impulse_noise/4 - Total images 7000 - 43.62s
# noise/impulse_noise/5 - Total images 7000 - 44.08s
# noise/impulse_noise/2 - Total images 8000 - 47.34s
# noise/impulse_noise/3 - Total images 8000 - 47.63s
# noise/impulse_noise/1 - Total images 8000 - 48.47s
# noise/impulse_noise/4 - Total images 8000 - 49.41s
# noise/impulse_noise/5 - Total images 8000 - 50.67s
# noise/impulse_noise/2 - Total images 9000 - 52.66s
# noise/impulse_noise/1 - Total images 9000 - 53.95s
# noise/impulse_noise/3 - Total images 9000 - 54.29s
# noise/impulse_noise/4 - Total images 9000 - 55.89s
# noise/impulse_noise/2 - Total images 10000 - 58.28s
# noise/impulse_noise/5 - Total images 9000 - 56.95s
# noise/impulse_noise/1 - Total images 10000 - 59.69s
# noise/impulse_noise/3 - Total images 10000 - 60.32s
# noise/impulse_noise/4 - Total images 10000 - 61.05s
# noise/impulse_noise/5 - Total images 10000 - 61.75s
# File save with success!
# Process predict started for noise/2/1
# noise/shot_noise/1 - Total images 0 - 0.01s
# Process predict started for noise/2/2
# noise/shot_noise/2 - Total images 0 - 0.01s
# Process predict started for noise/2/3
# noise/shot_noise/3 - Total images 0 - 0.01s
# Process predict started for noise/2/4
# noise/shot_noise/4 - Total images 0 - 0.01s
# Process predict started for noise/2/5
# noise/shot_noise/5 - Total images 0 - 0.01s
# noise/shot_noise/1 - Total images 1000 - 5.58s
# noise/shot_noise/2 - Total images 1000 - 5.84s
# noise/shot_noise/3 - Total images 1000 - 6.39s
# noise/shot_noise/4 - Total images 1000 - 5.95s
# noise/shot_noise/5 - Total images 1000 - 6.17s
# noise/shot_noise/1 - Total images 2000 - 11.62s
# noise/shot_noise/2 - Total images 2000 - 11.48s
# noise/shot_noise/4 - Total images 2000 - 12.26s
# noise/shot_noise/3 - Total images 2000 - 12.91s
# noise/shot_noise/5 - Total images 2000 - 12.30s
# noise/shot_noise/2 - Total images 3000 - 17.17s
# noise/shot_noise/1 - Total images 3000 - 18.19s
# noise/shot_noise/3 - Total images 3000 - 18.98s
# noise/shot_noise/4 - Total images 3000 - 18.89s
# noise/shot_noise/5 - Total images 3000 - 18.37s
# noise/shot_noise/2 - Total images 4000 - 23.17s
# noise/shot_noise/1 - Total images 4000 - 24.52s
# noise/shot_noise/3 - Total images 4000 - 25.02s
# noise/shot_noise/5 - Total images 4000 - 24.40s
# noise/shot_noise/4 - Total images 4000 - 25.48s
# noise/shot_noise/2 - Total images 5000 - 28.68s
# noise/shot_noise/1 - Total images 5000 - 30.80s
# noise/shot_noise/5 - Total images 5000 - 30.50s
# noise/shot_noise/3 - Total images 5000 - 31.56s
# noise/shot_noise/4 - Total images 5000 - 31.92s
# noise/shot_noise/2 - Total images 6000 - 34.71s
# noise/shot_noise/1 - Total images 6000 - 36.76s
# noise/shot_noise/3 - Total images 6000 - 37.52s
# noise/shot_noise/5 - Total images 6000 - 36.89s
# noise/shot_noise/4 - Total images 6000 - 38.26s
# noise/shot_noise/2 - Total images 7000 - 40.93s
# noise/shot_noise/1 - Total images 7000 - 42.45s
# noise/shot_noise/3 - Total images 7000 - 43.48s
# noise/shot_noise/5 - Total images 7000 - 43.42s
# noise/shot_noise/4 - Total images 7000 - 44.83s
# noise/shot_noise/1 - Total images 8000 - 47.57s
# noise/shot_noise/2 - Total images 8000 - 47.58s
# noise/shot_noise/3 - Total images 8000 - 49.36s
# noise/shot_noise/5 - Total images 8000 - 49.78s
# noise/shot_noise/4 - Total images 8000 - 51.18s
# noise/shot_noise/1 - Total images 9000 - 53.54s
# noise/shot_noise/2 - Total images 9000 - 53.65s
# noise/shot_noise/3 - Total images 9000 - 55.90s
# noise/shot_noise/5 - Total images 9000 - 55.53s
# noise/shot_noise/1 - Total images 10000 - 59.02s
# noise/shot_noise/4 - Total images 9000 - 57.85s
# noise/shot_noise/2 - Total images 10000 - 59.91s
# noise/shot_noise/3 - Total images 10000 - 61.48s
# noise/shot_noise/5 - Total images 10000 - 60.82s
# noise/shot_noise/4 - Total images 10000 - 62.67s
# File save with success!
# Process predict started for weather/0/1
# weather/brightness/1 - Total images 0 - 0.01s
# Process predict started for weather/0/2
# weather/brightness/2 - Total images 0 - 0.01s
# Process predict started for weather/0/3
# weather/brightness/3 - Total images 0 - 0.01s
# Process predict started for weather/0/4
# weather/brightness/4 - Total images 0 - 0.01s
# Process predict started for weather/0/5
# weather/brightness/5 - Total images 0 - 0.01s
# weather/brightness/1 - Total images 1000 - 5.23s
# weather/brightness/3 - Total images 1000 - 5.66s
# weather/brightness/2 - Total images 1000 - 6.08s
# weather/brightness/4 - Total images 1000 - 6.26s
# weather/brightness/5 - Total images 1000 - 6.37s
# weather/brightness/1 - Total images 2000 - 11.53s
# weather/brightness/3 - Total images 2000 - 11.58s
# weather/brightness/2 - Total images 2000 - 12.64s
# weather/brightness/4 - Total images 2000 - 12.08s
# weather/brightness/5 - Total images 2000 - 12.57s
# weather/brightness/1 - Total images 3000 - 17.92s
# weather/brightness/3 - Total images 3000 - 18.09s
# weather/brightness/4 - Total images 3000 - 17.68s
# weather/brightness/2 - Total images 3000 - 19.14s
# weather/brightness/5 - Total images 3000 - 18.12s
# weather/brightness/1 - Total images 4000 - 24.47s
# weather/brightness/4 - Total images 4000 - 23.24s
# weather/brightness/3 - Total images 4000 - 23.76s
# weather/brightness/2 - Total images 4000 - 25.68s
# weather/brightness/5 - Total images 4000 - 24.59s
# weather/brightness/1 - Total images 5000 - 30.30s
# weather/brightness/3 - Total images 5000 - 29.76s
# weather/brightness/4 - Total images 5000 - 29.53s
# weather/brightness/2 - Total images 5000 - 31.95s
# weather/brightness/5 - Total images 5000 - 31.22s
# weather/brightness/1 - Total images 6000 - 35.80s
# weather/brightness/3 - Total images 6000 - 35.67s
# weather/brightness/4 - Total images 6000 - 36.15s
# weather/brightness/2 - Total images 6000 - 37.70s
# weather/brightness/5 - Total images 6000 - 37.03s
# weather/brightness/1 - Total images 7000 - 42.02s
# weather/brightness/3 - Total images 7000 - 42.00s
# weather/brightness/4 - Total images 7000 - 42.49s
# weather/brightness/2 - Total images 7000 - 43.78s
# weather/brightness/5 - Total images 7000 - 43.11s
# weather/brightness/1 - Total images 8000 - 48.52s
# weather/brightness/3 - Total images 8000 - 47.82s
# weather/brightness/2 - Total images 8000 - 49.28s
# weather/brightness/4 - Total images 8000 - 48.92s
# weather/brightness/5 - Total images 8000 - 49.45s
# weather/brightness/3 - Total images 9000 - 53.66s
# weather/brightness/1 - Total images 9000 - 55.14s
# weather/brightness/2 - Total images 9000 - 55.33s
# weather/brightness/4 - Total images 9000 - 55.11s
# weather/brightness/5 - Total images 9000 - 55.64s
# weather/brightness/3 - Total images 10000 - 59.59s
# weather/brightness/1 - Total images 10000 - 61.29s
# weather/brightness/2 - Total images 10000 - 61.66s
# weather/brightness/4 - Total images 10000 - 60.85s
# weather/brightness/5 - Total images 10000 - 60.86s
# File save with success!
# Process predict started for weather/1/1
# weather/fog/1 - Total images 0 - 0.01s
# Process predict started for weather/1/2
# weather/fog/2 - Total images 0 - 0.01s
# Process predict started for weather/1/3
# weather/fog/3 - Total images 0 - 0.01s
# Process predict started for weather/1/4
# weather/fog/4 - Total images 0 - 0.01s
# Process predict started for weather/1/5
# weather/fog/5 - Total images 0 - 0.01s
# weather/fog/1 - Total images 1000 - 6.16s
# weather/fog/2 - Total images 1000 - 6.17s
# weather/fog/3 - Total images 1000 - 5.84s
# weather/fog/4 - Total images 1000 - 5.93s
# weather/fog/5 - Total images 1000 - 6.60s
# weather/fog/3 - Total images 2000 - 11.64s
# weather/fog/4 - Total images 2000 - 11.25s
# weather/fog/1 - Total images 2000 - 12.63s
# weather/fog/2 - Total images 2000 - 12.61s
# weather/fog/5 - Total images 2000 - 13.19s
# weather/fog/3 - Total images 3000 - 17.39s
# weather/fog/4 - Total images 3000 - 17.54s
# weather/fog/2 - Total images 3000 - 18.43s
# weather/fog/1 - Total images 3000 - 19.18s
# weather/fog/5 - Total images 3000 - 19.74s
# weather/fog/3 - Total images 4000 - 23.65s
# weather/fog/4 - Total images 4000 - 23.59s
# weather/fog/2 - Total images 4000 - 24.42s
# weather/fog/1 - Total images 4000 - 25.72s
# weather/fog/5 - Total images 4000 - 26.09s
# weather/fog/4 - Total images 5000 - 29.27s
# weather/fog/3 - Total images 5000 - 29.91s
# weather/fog/2 - Total images 5000 - 30.73s
# weather/fog/1 - Total images 5000 - 31.48s
# weather/fog/5 - Total images 5000 - 32.51s
# weather/fog/4 - Total images 6000 - 35.37s
# weather/fog/3 - Total images 6000 - 36.03s
# weather/fog/2 - Total images 6000 - 37.08s
# weather/fog/1 - Total images 6000 - 37.81s
# weather/fog/5 - Total images 6000 - 39.05s
# weather/fog/4 - Total images 7000 - 41.05s
# weather/fog/3 - Total images 7000 - 42.03s
# weather/fog/1 - Total images 7000 - 43.74s
# weather/fog/2 - Total images 7000 - 43.38s
# weather/fog/5 - Total images 7000 - 45.54s
# weather/fog/4 - Total images 8000 - 47.10s
# weather/fog/3 - Total images 8000 - 47.80s
# weather/fog/2 - Total images 8000 - 49.44s
# weather/fog/1 - Total images 8000 - 50.23s
# weather/fog/5 - Total images 8000 - 52.03s
# weather/fog/4 - Total images 9000 - 52.76s
# weather/fog/3 - Total images 9000 - 54.18s
# weather/fog/2 - Total images 9000 - 55.42s
# weather/fog/1 - Total images 9000 - 56.73s
# weather/fog/4 - Total images 10000 - 58.67s
# weather/fog/5 - Total images 9000 - 58.51s
# weather/fog/3 - Total images 10000 - 60.70s
# weather/fog/2 - Total images 10000 - 61.15s
# weather/fog/1 - Total images 10000 - 62.13s
# weather/fog/5 - Total images 10000 - 63.22s
# File save with success!
# Process predict started for weather/2/1
# weather/frost/1 - Total images 0 - 0.01s
# Process predict started for weather/2/2
# weather/frost/2 - Total images 0 - 0.01s
# Process predict started for weather/2/3
# weather/frost/3 - Total images 0 - 0.01s
# Process predict started for weather/2/4
# weather/frost/4 - Total images 0 - 0.01s
# Process predict started for weather/2/5
# weather/frost/5 - Total images 0 - 0.01s
# weather/frost/2 - Total images 1000 - 5.42s
# weather/frost/1 - Total images 1000 - 5.86s
# weather/frost/3 - Total images 1000 - 5.43s
# weather/frost/4 - Total images 1000 - 6.53s
# weather/frost/5 - Total images 1000 - 6.52s
# weather/frost/2 - Total images 2000 - 11.54s
# weather/frost/3 - Total images 2000 - 11.33s
# weather/frost/1 - Total images 2000 - 12.16s
# weather/frost/5 - Total images 2000 - 12.41s
# weather/frost/4 - Total images 2000 - 13.10s
# weather/frost/3 - Total images 3000 - 16.88s
# weather/frost/1 - Total images 3000 - 18.35s
# weather/frost/2 - Total images 3000 - 18.21s
# weather/frost/5 - Total images 3000 - 18.28s
# weather/frost/4 - Total images 3000 - 19.53s
# weather/frost/3 - Total images 4000 - 23.36s
# weather/frost/2 - Total images 4000 - 23.93s
# weather/frost/1 - Total images 4000 - 24.70s
# weather/frost/5 - Total images 4000 - 24.30s
# weather/frost/4 - Total images 4000 - 26.09s
# weather/frost/1 - Total images 5000 - 30.14s
# weather/frost/3 - Total images 5000 - 29.84s
# weather/frost/2 - Total images 5000 - 30.34s
# weather/frost/5 - Total images 5000 - 29.91s
# weather/frost/4 - Total images 5000 - 32.64s
# weather/frost/3 - Total images 6000 - 35.18s
# weather/frost/1 - Total images 6000 - 36.67s
# weather/frost/2 - Total images 6000 - 36.84s
# weather/frost/5 - Total images 6000 - 35.62s
# weather/frost/4 - Total images 6000 - 38.88s
# weather/frost/3 - Total images 7000 - 41.20s
# weather/frost/1 - Total images 7000 - 43.19s
# weather/frost/2 - Total images 7000 - 43.42s
# weather/frost/5 - Total images 7000 - 41.88s
# weather/frost/4 - Total images 7000 - 44.56s
# weather/frost/3 - Total images 8000 - 46.74s
# weather/frost/5 - Total images 8000 - 47.23s
# weather/frost/1 - Total images 8000 - 49.71s
# weather/frost/2 - Total images 8000 - 50.02s
# weather/frost/4 - Total images 8000 - 50.80s
# weather/frost/3 - Total images 9000 - 52.99s
# weather/frost/5 - Total images 9000 - 53.43s
# weather/frost/1 - Total images 9000 - 55.50s
# weather/frost/2 - Total images 9000 - 56.51s
# weather/frost/4 - Total images 9000 - 56.64s
# weather/frost/3 - Total images 10000 - 59.40s
# weather/frost/5 - Total images 10000 - 58.80s
# weather/frost/1 - Total images 10000 - 61.49s
# weather/frost/2 - Total images 10000 - 62.15s
# weather/frost/4 - Total images 10000 - 61.72s
# File save with success!
# Process predict started for weather/3/1
# weather/snow/1 - Total images 0 - 0.01s
# Process predict started for weather/3/2
# weather/snow/2 - Total images 0 - 0.01s
# Process predict started for weather/3/3
# weather/snow/3 - Total images 0 - 0.01s
# Process predict started for weather/3/4
# weather/snow/4 - Total images 0 - 0.01s
# Process predict started for weather/3/5
# weather/snow/5 - Total images 0 - 0.01s
# weather/snow/1 - Total images 1000 - 5.60s
# weather/snow/2 - Total images 1000 - 5.78s
# weather/snow/3 - Total images 1000 - 6.48s
# weather/snow/5 - Total images 1000 - 5.71s
# weather/snow/4 - Total images 1000 - 6.57s
# weather/snow/1 - Total images 2000 - 11.20s
# weather/snow/2 - Total images 2000 - 12.30s
# weather/snow/5 - Total images 2000 - 11.34s
# weather/snow/3 - Total images 2000 - 13.01s
# weather/snow/4 - Total images 2000 - 12.96s
# weather/snow/1 - Total images 3000 - 17.17s
# weather/snow/2 - Total images 3000 - 18.48s
# weather/snow/5 - Total images 3000 - 17.76s
# weather/snow/3 - Total images 3000 - 19.33s
# weather/snow/4 - Total images 3000 - 18.98s
# weather/snow/1 - Total images 4000 - 23.66s
# weather/snow/2 - Total images 4000 - 23.95s
# weather/snow/3 - Total images 4000 - 24.86s
# weather/snow/5 - Total images 4000 - 24.27s
# weather/snow/4 - Total images 4000 - 25.37s
# weather/snow/1 - Total images 5000 - 30.12s
# weather/snow/2 - Total images 5000 - 30.23s
# weather/snow/3 - Total images 5000 - 31.14s
# weather/snow/5 - Total images 5000 - 30.43s
# weather/snow/4 - Total images 5000 - 31.18s
# weather/snow/1 - Total images 6000 - 35.54s
# weather/snow/2 - Total images 6000 - 36.07s
# weather/snow/4 - Total images 6000 - 37.10s
# weather/snow/3 - Total images 6000 - 37.67s
# weather/snow/5 - Total images 6000 - 36.94s
# weather/snow/1 - Total images 7000 - 40.86s
# weather/snow/2 - Total images 7000 - 41.95s
# weather/snow/4 - Total images 7000 - 43.50s
# weather/snow/3 - Total images 7000 - 44.17s
# weather/snow/5 - Total images 7000 - 43.30s
# weather/snow/1 - Total images 8000 - 47.02s
# weather/snow/2 - Total images 8000 - 48.03s
# weather/snow/3 - Total images 8000 - 49.78s
# weather/snow/4 - Total images 8000 - 49.58s
# weather/snow/5 - Total images 8000 - 49.65s
# weather/snow/1 - Total images 9000 - 52.53s
# weather/snow/2 - Total images 9000 - 54.68s
# weather/snow/3 - Total images 9000 - 56.12s
# weather/snow/5 - Total images 9000 - 55.14s
# weather/snow/4 - Total images 9000 - 56.12s
# weather/snow/1 - Total images 10000 - 58.06s
# weather/snow/2 - Total images 10000 - 60.30s
# weather/snow/3 - Total images 10000 - 61.46s
# weather/snow/5 - Total images 10000 - 60.56s
# weather/snow/4 - Total images 10000 - 61.67s
# File save with success!
